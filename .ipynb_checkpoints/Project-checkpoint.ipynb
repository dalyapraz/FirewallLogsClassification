# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# ignore warnigns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
log_df = pd.read_csv('log2.csv')
#log_df.info()

# %%
log_df.head()
log_df.shape
log_df['Action'].value_counts()
# Out:
# allow         37640
# deny          14987
# drop          12851
# reset-both       54
# Name: Action, dtype: int64

# %%
# 'reset_both' and ' drop' change to 'deny'
#log_df.loc[log_df['Action'] !='allow', 'Action'] = 'not allow'

# %%
sns.set(rc={"figure.figsize": (5, 5)})
sns.countplot(log_df['Action'])
# Out:
# <AxesSubplot:xlabel='Action', ylabel='count'>

# %%
test = log_df[log_df['Action'] !='allow']
test['Source Port'].unique().shape
# Out:
# (13728,)

# %%
log_df.columns
# Out:
# Index(['Source Port', 'Destination Port', 'NAT Source Port',
#        'NAT Destination Port', 'Action', 'Bytes', 'Bytes Sent',
#        'Bytes Received', 'Packets', 'Elapsed Time (sec)', 'pkts_sent',
#        'pkts_received'],
#       dtype='object')

# %%
log_df = log_df[['Source Port','Destination Port', 'NAT Source Port', 'NAT Destination Port', 'Action']]
log_df = log_df.drop_duplicates()
log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53277 entries, 0 to 65530
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Source Port           53277 non-null  int64
#  1   Destination Port      53277 non-null  int64
#  2   NAT Source Port       53277 non-null  int64
#  3   NAT Destination Port  53277 non-null  int64
#  4   Action                53277 non-null  object
# dtypes: int64(4), object(1)
# memory usage: 2.4+ MB

# %%
categorical= log_df[['Source Port','Destination Port', 'NAT Source Port', 'NAT Destination Port']]

print('Categorical features: ',list(categorical.columns)) # categorical features
# Out:
# Categorical features:  ['Source Port', 'Destination Port', 'NAT Source Port', 'NAT Destination Port']

# %%
from sklearn import preprocessing

# transforming categorical variables
le = preprocessing.LabelEncoder()
log_df['Action'] = le.fit_transform(log_df['Action'])
log_df['Action'].unique()
sns.set(rc={"figure.figsize": (5, 5)})
sns.countplot(log_df['Action'])
# Out:
# <AxesSubplot:xlabel='Action', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
x = categorical
y = log_df[['Action']]

# %%
# %%time
from imblearn.over_sampling import SMOTE, ADASYN
x_resampled, y_resampled = SMOTE().fit_resample(x, y)
sns.set(rc={"figure.figsize": (5, 5)})
sns.countplot(y_resampled['Action'])
# Out:
# CPU times: user 300 ms, sys: 12.3 ms, total: 313 ms
# Wall time: 120 ms
# <AxesSubplot:xlabel='Action', ylabel='count'>

# %%
# train and test split
X_train, X_test, y_train, y_test = train_test_split(x_resampled, y_resampled,test_size=0.33,
                                                   random_state = 123)

# %%
# %%time
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

cat_features = list(categorical.columns)
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(sparse = True))])
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, cat_features)])

preprocessor.fit(x_resampled)

# transform train and test data
X_train_transformed = preprocessor.transform(X_train)
X_test_transformed = preprocessor.transform(X_test)
# Out:
# CPU times: user 574 ms, sys: 26.5 ms, total: 601 ms
# Wall time: 180 ms

# %%
# %%time
# SVM
from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(X_train_transformed, y_train)
svm_scores = svm.score(X_test_transformed, y_test)
y_pred_svm = svm.predict(X_test_transformed)
print('Score for SVM {}'.format(svm_scores))
# Out:
# /Users/dalyapraz/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Score for SVM 0.9176258043562106
# CPU times: user 5min 36s, sys: 3.09 s, total: 5min 39s
# Wall time: 5min 38s

# %%
# %%time
# KNC
from sklearn.neighbors import KNeighborsClassifier
knc = KNeighborsClassifier()
knc.fit(X_train_transformed, y_train)
knc_scores = knc.score(X_test_transformed, y_test)
y_pred_knc = knc.predict(X_test_transformed)
print('Score for KNeighborsClassifier {}'.format(knc_scores))
# Out:
# /Users/dalyapraz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   after removing the cwd from sys.path.
# Score for KNeighborsClassifier 0.856342488277206
# CPU times: user 5min 1s, sys: 1min 14s, total: 6min 16s
# Wall time: 4min 36s

# %%
# %%time
# Random Forest Model
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10)
rfc.fit(X_test_transformed, y_test)
y_pred_rfc = rfc.predict(X_test_transformed)
rfc_scores = rfc.score(X_test_transformed, y_test)
print('Score for RandomForestClassifier {}'.format(rfc_scores))
# Out:
# /Users/dalyapraz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# Score for RandomForestClassifier 0.989099324036295
# CPU times: user 39.3 s, sys: 74.8 ms, total: 39.4 s
# Wall time: 39.4 s

# %%
# %%time
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

#SVM
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_svm = recall_score(y_test, y_pred_svm, average='macro')
print('Recall SVM: %.3f' % recall_svm)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_svm = precision_score(y_test, y_pred_svm, average='macro')
print('Precision SVM: %.3f' % precision_svm)

f1_svm = f1_score(y_test, y_pred_svm, average='macro')
print('F1 score SVM: %.3f' % f1_svm)

#KNN
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_knc = recall_score(y_test, y_pred_knc, average='macro')
print('Recall KNeighborsClassifier: %.3f' % recall_knc)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_knc = precision_score(y_test, y_pred_knc, average='macro')
print('Precision KNeighborsClassifier: %.3f' % precision_knc)

f1_knc = f1_score(y_test, y_pred_knc, average='macro')
print('F1 score KNeighborsClassifier: %.3f' % f1_knc)

#RandomForest
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_rfc = recall_score(y_test, y_pred_rfc, average='macro')
print('Recall RandomForestClassifier: %.3f' % recall_rfc)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_rfc = precision_score(y_test, y_pred_rfc, average='macro')
print('Precision RandomForestClassifier: %.3f' % precision_rfc)

f1_rfc = f1_score(y_test, y_pred_rfc, average='macro')
print('F1 score RandomForestClassifier: %.3f' % f1_rfc)
# Out:
# Recall SVM: 0.918
# Precision SVM: 0.922
# F1 score SVM: 0.917
# Recall KNeighborsClassifier: 0.855
# Precision KNeighborsClassifier: 0.876
# F1 score KNeighborsClassifier: 0.848
# Recall RandomForestClassifier: 0.989
# Precision RandomForestClassifier: 0.989
# F1 score RandomForestClassifier: 0.989
# CPU times: user 131 ms, sys: 2.94 ms, total: 134 ms
# Wall time: 132 ms

# %%
# %%time
from sklearn.metrics import plot_confusion_matrix
labels = ['allow', 'deny', 'drop', 'reset']
plot_confusion_matrix(svm, X_test_transformed, y_test, cmap = 'Blues', display_labels = labels)
plot_confusion_matrix(knc, X_test_transformed, y_test, cmap = 'Blues', display_labels = labels)
plot_confusion_matrix(rfc, X_test_transformed, y_test, cmap = 'Blues', display_labels = labels)
plt.show()
# Out:
# CPU times: user 3min 7s, sys: 29.8 s, total: 3min 37s
# Wall time: 2min 32s

# %%
import numpy as np


def plot_cm(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
# SVM and KNC, RF
from sklearn.metrics import confusion_matrix
cm_svm = confusion_matrix(y_test, y_pred_svm)
cm_knc = confusion_matrix(y_test, y_pred_knc)
cm_rfc = confusion_matrix(y_test, y_pred_rfc)
labels = ['allow', 'deny', 'drop', 'reset']
plot_cm(cm_svm, labels, title = 'Confusion Matrix SVM')
plot_cm(cm_knc, labels, title = 'Confusion Matrix KNC')
plot_cm(cm_rfc, labels, title = 'Confusion Matrix Random Forest')

# %% [markdown]
# ### without SMOTE

# %%
# train and test split
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.33,
                                                   random_state = 123)

# %%
# %%time
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

cat_features = list(categorical.columns)
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(sparse = True))])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, cat_features)])

preprocessor.fit(x)

# transform train and test data
X_train_transformed = preprocessor.transform(X_train)
X_test_transformed = preprocessor.transform(X_test)
# Out:
# CPU times: user 66.2 ms, sys: 4.99 ms, total: 71.2 ms
# Wall time: 70.2 ms

# %%
# %%time
# SVM
from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(X_train_transformed, y_train)
svm_scores = svm.score(X_test_transformed, y_test)
y_pred_svm = svm.predict(X_test_transformed)
print('Score for SVM {}'.format(svm_scores))
# Out:
# /Users/dalyapraz/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Score for SVM 0.9973268115117734
# CPU times: user 14.7 s, sys: 406 ms, total: 15.1 s
# Wall time: 14.2 s

# %%
# %%time
# KNC
from sklearn.neighbors import KNeighborsClassifier
knc = KNeighborsClassifier()
knc.fit(X_train_transformed, y_train)
knc_scores = knc.score(X_test_transformed, y_test)
y_pred_knc = knc.predict(X_test_transformed)
print('Score for KNeighborsClassifier {}'.format(knc_scores))
# Out:
# /Users/dalyapraz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   after removing the cwd from sys.path.
# Score for KNeighborsClassifier 0.9899328859060402
# CPU times: user 31.8 s, sys: 6.81 s, total: 38.6 s
# Wall time: 25.5 s

# %%
# %%time
# Random Forest Model
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10)
rfc.fit(X_test_transformed, y_test)
y_pred_rfc = rfc.predict(X_test_transformed)
rfc_scores = rfc.score(X_test_transformed, y_test)
print('Score for RandomForestClassifier {}'.format(rfc_scores))
# Out:
# /Users/dalyapraz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# Score for RandomForestClassifier 0.9994312364918667
# CPU times: user 3.24 s, sys: 11.8 ms, total: 3.25 s
# Wall time: 3.26 s

# %%
# %%time
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

#SVM
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_svm = recall_score(y_test, y_pred_svm, average='macro')
print('Recall SVM: %.3f' % recall_svm)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_svm = precision_score(y_test, y_pred_svm, average='macro')
print('Precision SVM: %.3f' % precision_svm)

f1_svm = f1_score(y_test, y_pred_svm, average='macro')
print('F1 score SVM: %.3f' % f1_svm)

#KNN
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_knc = recall_score(y_test, y_pred_knc, average='macro')
print('Recall KNeighborsClassifier: %.3f' % recall_knc)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_knc = precision_score(y_test, y_pred_knc, average='macro')
print('Precision KNeighborsClassifier: %.3f' % precision_knc)

f1_knc = f1_score(y_test, y_pred_knc, average='macro')
print('F1 score KNeighborsClassifier: %.3f' % f1_knc)

#RandomForest
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_rfc = recall_score(y_test, y_pred_rfc, average='macro')
print('Recall RandomForestClassifier: %.3f' % recall_rfc)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_rfc = precision_score(y_test, y_pred_rfc, average='macro')
print('Precision RandomForestClassifier: %.3f' % precision_rfc)

f1_rfc = f1_score(y_test, y_pred_rfc, average='macro')
print('F1 score RandomForestClassifier: %.3f' % f1_rfc)
# Out:
# Recall SVM: 0.859
# Precision SVM: 0.934
# F1 score SVM: 0.887
# Recall KNeighborsClassifier: 0.821
# Precision KNeighborsClassifier: 0.931
# F1 score KNeighborsClassifier: 0.856
# Recall RandomForestClassifier: 0.950
# Precision RandomForestClassifier: 0.999
# F1 score RandomForestClassifier: 0.972
# CPU times: user 41.3 ms, sys: 2.34 ms, total: 43.6 ms
# Wall time: 42.1 ms

# %%
# SVM and KNC, RF
#%%time
cm_svm = confusion_matrix(y_test, y_pred_svm)
cm_knc = confusion_matrix(y_test, y_pred_knc)
cm_rfc = confusion_matrix(y_test, y_pred_rfc)
labels = ['allow', 'deny', 'drop', 'reset']
plot_cm(cm_svm, labels, title = 'Confusion Matrix SVM')
plot_cm(cm_knc, labels, title = 'Confusion Matrix KNC')
plot_cm(cm_rfc, labels, title = 'Confusion Matrix Random Forest')

# %%
# %%time
from sklearn.metrics import plot_confusion_matrix
labels = ['allow', 'deny', 'drop', 'reset']
plot_confusion_matrix(svm, X_test_transformed, y_test, cmap = 'Blues', display_labels = labels)
plot_confusion_matrix(knc, X_test_transformed, y_test, cmap = 'Blues', display_labels = labels)
plot_confusion_matrix(rfc, X_test_transformed, y_test, cmap = 'Blues', display_labels = labels)
plt.show()
# Out:
# CPU times: user 19.2 s, sys: 3.43 s, total: 22.6 s
# Wall time: 16 s

# %% [markdown]
# ### NO Smote and NO OneHotCoding

# %%
# train and test split
x = categorical
y = log_df['Action']
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.33,
                                                   random_state = 123)

# %%
# %%time
# SVM
from sklearn.svm import SVC
svm = SVC(kernel='rbf')
svm.fit(X_train, y_train)
svm_scores = svm.score(X_test, y_test)
y_pred_svm = svm.predict(X_test)
print('Score for SVM {}'.format(svm_scores))
# Out:
# Score for SVM 0.9819133204413605
# CPU times: user 6.4 s, sys: 190 ms, total: 6.59 s
# Wall time: 5.66 s

# %%
# %%time
# KNC
from sklearn.neighbors import KNeighborsClassifier
knc = KNeighborsClassifier()
knc.fit(X_train, y_train)
knc_scores = knc.score(X_test, y_test)
y_pred_knc = knc.predict(X_test)
print('Score for KNeighborsClassifier {}'.format(knc_scores))
# Out:
# Score for KNeighborsClassifier 0.9912410419747469
# CPU times: user 2.92 s, sys: 27.8 ms, total: 2.95 s
# Wall time: 1.09 s

# %%
# %%time
# Random Forest Model
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10)
rfc.fit(X_test, y_test)
y_pred_rfc = rfc.predict(X_test)
rfc_scores = rfc.score(X_test, y_test)
print('Score for RandomForestClassifier {}'.format(rfc_scores))
# Out:
# Score for RandomForestClassifier 0.9990899783869867
# CPU times: user 134 ms, sys: 8.15 ms, total: 142 ms
# Wall time: 151 ms

# %%
# %%time
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

#SVM
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_svm = recall_score(y_test, y_pred_svm, average='macro')
print('Recall SVM: %.3f' % recall_svm)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_svm = precision_score(y_test, y_pred_svm, average='macro')
print('Precision SVM: %.3f' % precision_svm)

f1_svm = f1_score(y_test, y_pred_svm, average='macro')
print('F1 score SVM: %.3f' % f1_svm)

#KNN
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_knc = recall_score(y_test, y_pred_knc, average='macro')
print('Recall KNeighborsClassifier: %.3f' % recall_knc)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_knc = precision_score(y_test, y_pred_knc, average='macro')
print('Precision KNeighborsClassifier: %.3f' % precision_knc)

f1_knc = f1_score(y_test, y_pred_knc, average='macro')
print('F1 score KNeighborsClassifier: %.3f' % f1_knc)

#RandomForest
# calculate recall (Recall = TruePositives / (TruePositives + FalseNegatives))
recall_rfc = recall_score(y_test, y_pred_rfc, average='macro')
print('Recall RandomForestClassifier: %.3f' % recall_rfc)

# calculate precision (Precision = TruePositives / (TruePositives + FalsePositives))
precision_rfc = precision_score(y_test, y_pred_rfc, average='macro')
print('Precision RandomForestClassifier: %.3f' % precision_rfc)

f1_rfc = f1_score(y_test, y_pred_rfc, average='macro')
print('F1 score RandomForestClassifier: %.3f' % f1_rfc)
# Out:
# Recall SVM: 0.732
# Precision SVM: 0.724
# F1 score SVM: 0.728
# Recall KNeighborsClassifier: 0.742
# Precision KNeighborsClassifier: 0.736
# F1 score KNeighborsClassifier: 0.739
# Recall RandomForestClassifier: 0.937
# Precision RandomForestClassifier: 0.999
# F1 score RandomForestClassifier: 0.963
# CPU times: user 47.7 ms, sys: 2.7 ms, total: 50.4 ms
# Wall time: 48.8 ms
# /Users/dalyapraz/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %%time
from sklearn.metrics import plot_confusion_matrix
labels = ['allow', 'deny', 'drop', 'reset']
plot_confusion_matrix(svm, X_test, y_test, cmap = 'Blues', display_labels = labels)
plot_confusion_matrix(knc, X_test, y_test, cmap = 'Blues', display_labels = labels)
plot_confusion_matrix(rfc, X_test, y_test, cmap = 'Blues', display_labels = labels)
plt.show()
# Out:
# CPU times: user 2.65 s, sys: 36.2 ms, total: 2.68 s
# Wall time: 1.74 s
